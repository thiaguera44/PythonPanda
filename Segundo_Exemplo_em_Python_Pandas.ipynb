# %% [markdown]
# <a href="https://colab.research.google.com/github/thiaguera44/PythonPanda/blob/main/Segundo_Exemplo_em_Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Segundo exemplo de manipulação de dados usando Python Pandas**
#
# Data: 09  e 10 de fevereiro de 2023

# %%
# Importando biblioteca pandas no Python

import pandas as pd

combustiveis_df = pd.read_excel('precos.xlsx')

# %%
display(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#Inserção de dados simples

combustiveis_df['Ativo'] = True

display(combustiveis_df.head(5))
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
# Vou colocar uma coluna chamada "OBS"
# que preencha automaticamente "MELHOR CIDADE"
# quando o municipio for BELO HORIZONTE, MG...

combustiveis_df['Obs'] = ['MELHOR CIDADE' if municipio == 'BELO HORIZONTE' else '' for municipio in combustiveis_df['Municipio']]
  
display(combustiveis_df.loc[combustiveis_df['Municipio'].isin(['BELO HORIZONTE','INDAIATUBA','CONTAGEM']),['Municipio','Obs']])
# Out:
#              Municipio            Obs
# 385           CONTAGEM
# 386           CONTAGEM
# 387           CONTAGEM
# 388           CONTAGEM
# 389           CONTAGEM
# ...                ...            ...
# 166510  BELO HORIZONTE  MELHOR CIDADE
# 166511  BELO HORIZONTE  MELHOR CIDADE
# 166545  BELO HORIZONTE  MELHOR CIDADE
# 166546  BELO HORIZONTE  MELHOR CIDADE
# 166547  BELO HORIZONTE  MELHOR CIDADE
#
# [2000 rows x 2 columns]

# %%
# Preencher uma coluna "Valor de Venda - Satus" que verifica:
# se o valor de venda for maior que 6,50 , ele avisa que está caro

import numpy as np

combustiveis_df['Valor de Venda - Status'] = np.where(combustiveis_df['Valor de Venda'] > 6.5, 'Está caro', 'Está barato')

display(combustiveis_df[['Municipio','Produto','Valor de Venda', 'Valor de Venda - Status']].head(10))
# Out:
#          Municipio             Produto  Valor de Venda Valor de Venda - Status
# 0        ARAPIRACA            GASOLINA           6.799               Está caro
# 1        ARAPIRACA              ETANOL           5.299             Está barato
# 2        ARAPIRACA              DIESEL           5.549             Está barato
# 3        ARAPIRACA  GASOLINA ADITIVADA           6.899               Está caro
# 4        ARAPIRACA          DIESEL S10           5.649             Está barato
# 5  DELMIRO GOUVEIA            GASOLINA           7.198               Está caro
# 6  DELMIRO GOUVEIA              ETANOL           5.982             Está barato
# 7  DELMIRO GOUVEIA              DIESEL           5.974             Está barato
# 8  DELMIRO GOUVEIA  GASOLINA ADITIVADA           7.208               Está caro
# 9  DELMIRO GOUVEIA          DIESEL S10           5.983             Está barato

# %%
# Calcular postos de gasolina por abitante na amostragem de combustiveis nov/2021

num_hab_df = pd.read_csv("ibge_num_habitantes_estimado.csv", sep=";")
num_hab_df.rename(columns = {"Estado":"Estado - Sigla"}, inplace=True)

display(num_hab_df)
# Out:
#          Municipio Estado - Sigla  NumHabitantes2021
# 0   BELO HORIZONTE             MG            2530701
# 1         CAMPINAS             SP            1223237
# 2     CAMPO GRANDE             MS             916001
# 3         CURITIBA             PR            1963726
# 4          GOIANIA             GO            1555626
# 5       INDAIATUBA             SP             260690
# 6            NATAL             RN             803739
# 7           PALMAS             TO             313349
# 8        PENAPOLIS             SP              64098
# 9     PORTO ALEGRE             RS            1492530
# 10     PORTO VELHO             RO             548952
# 11      RIO BRANCO             AC             419452
# 12  RIO DE JANEIRO             RJ            6775561
# 13    SALTO GRANDE             SP               9396
# 14          SANTOS             SP             433991
# 15       SAO PAULO             SP           12396372
# 16     SAO VICENTE             SP             370839
# ...

# %%
# MERGE dos dois dataframes
colunas = ['Municipio', 'Estado - Sigla']
merge_df = combustiveis_df.merge(num_hab_df, how="inner", on=colunas)
display(merge_df)
print(merge_df.info())
# Out:
#       Regiao - Sigla Estado - Sigla   Municipio  \
# 0                 CO             GO     GOIANIA
# 1                 CO             GO     GOIANIA
# 2                 CO             GO     GOIANIA
# 3                 CO             GO     GOIANIA
# 4                 CO             GO     GOIANIA
# ...              ...            ...         ...
# 20629             SE             SP  INDAIATUBA
# 20630             SE             SP  INDAIATUBA
# 20631             SE             SP  INDAIATUBA
# 20632             SE             SP  INDAIATUBA
# 20633             SE             SP  INDAIATUBA
#
#                                          Revenda      CNPJ da Revenda  \
# 0                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 1                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 2                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 3                              POSTO DO BOI LTDA   06.880.293/0001-25
# ...

# %%
#destruir coluna completamente vazia 

merge_df.dropna(axis=1, inplace = True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Regiao - Sigla           20634 non-null  object
#  1   Estado - Sigla           20634 non-null  object
#  2   Municipio                20634 non-null  object
#  3   Revenda                  20634 non-null  object
#  4   CNPJ da Revenda          20634 non-null  object
#  5   Nome da Rua              20634 non-null  object
#  6   Numero Rua               20634 non-null  object
#  7   Bairro                   20634 non-null  object
#  8   Cep                      20634 non-null  object
#  9   Produto                  20634 non-null  object
#  10  Data da Coleta           20634 non-null  datetime64[ns]
#  11  Valor de Venda           20634 non-null  float64
#  12  Unidade de Medida        20634 non-null  object
# ...

# %%
colunas = ['Regiao - Sigla', 'Nome da Rua','Numero Rua', 'Bairro', 
           'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda', 
           'Unidade de Medida', 'Bandeira','Ativo', 'Valor de Venda - Status']

merge_df.drop(labels = colunas, axis = 1, inplace = True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Estado - Sigla     20634 non-null  object
#  1   Municipio          20634 non-null  object
#  2   Revenda            20634 non-null  object
#  3   CNPJ da Revenda    20634 non-null  object
#  4   Obs                20634 non-null  object
#  5   NumHabitantes2021  20634 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 1.1+ MB
# None

# %%
display(merge_df.head(100))
# Out:
#    Estado - Sigla Municipio                       Revenda  \
# 0              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 1              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 2              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 3              GO   GOIANIA             POSTO DO BOI LTDA
# 4              GO   GOIANIA             POSTO DO BOI LTDA
# ..            ...       ...                           ...
# 95             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 96             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 97             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 98             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 99             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
#
#         CNPJ da Revenda Obs  NumHabitantes2021
# 0    37.831.484/0001-20                1555626
# 1    37.831.484/0001-20                1555626
# 2    37.831.484/0001-20                1555626
# 3    06.880.293/0001-25                1555626
# ...

# %%
#Removendo linhas duplicadas
merge_df.drop_duplicates(inplace = True)

display(merge_df)
# Out:
#       Estado - Sigla   Municipio                                Revenda  \
# 0                 GO     GOIANIA              AERO SETE AUTO POSTO LTDA
# 3                 GO     GOIANIA                      POSTO DO BOI LTDA
# 7                 GO     GOIANIA                          POSTO DN LTDA
# 11                GO     GOIANIA                      POSTO ALDEIA LTDA
# 15                GO     GOIANIA            AUTO POSTO SANTA LUZIA LTDA
# ...              ...         ...                                    ...
# 20431             SP  INDAIATUBA              AUTO POSTO GARATEIA LTDA.
# 20463             SP  INDAIATUBA          AUTO POSTO SAO PAULO LIMITADA
# 20491             SP  INDAIATUBA              AUTO POSTO EKKO PARK LTDA
# 20579             SP  INDAIATUBA  AUTO POSTO SANTOS DUMONT KM 48,5 LTDA
# 20608             SP  INDAIATUBA     AUTO POSTO DISTRITO DE INDAIA LTDA
#
#            CNPJ da Revenda Obs  NumHabitantes2021
# 0       37.831.484/0001-20                1555626
# ...

# %%
#Agrupar e contar quantos postos tem na cidade..

postos_por_municipio_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()
postos_por_municipio_df.reset_index(inplace = True)

postos_por_municipio_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_municipio_df.rename(columns={"Revenda": "Numero de Postos"}, inplace=True)
display(postos_por_municipio_df)
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  Numero de Postos  Obs
# 0              AC      RIO BRANCO             419452                44   44
# 1              GO         GOIANIA            1555626                93   93
# 2              MG  BELO HORIZONTE            2530701                54   54
# 3              MS    CAMPO GRANDE             916001               104  104
# 4              PR        CURITIBA            1963726               110  110
# 5              RJ  RIO DE JANEIRO            6775561               379  379
# 6              RN           NATAL             803739                37   37
# 7              RO     PORTO VELHO             548952                40   40
# 8              RS    PORTO ALEGRE            1492530                73   73
# 9              SP        CAMPINAS            1223237                51   51
# 10             SP      INDAIATUBA             260690                36   36
# ...

# %%
postos_por_municipio_df['HbitantePorPosto'] = postos_por_municipio_df['NumHabitantes2021']  / postos_por_municipio_df['Numero de Postos']

display(postos_por_municipio_df)
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  Numero de Postos  Obs  \
# 0              AC      RIO BRANCO             419452                44   44
# 1              GO         GOIANIA            1555626                93   93
# 2              MG  BELO HORIZONTE            2530701                54   54
# 3              MS    CAMPO GRANDE             916001               104  104
# 4              PR        CURITIBA            1963726               110  110
# 5              RJ  RIO DE JANEIRO            6775561               379  379
# 6              RN           NATAL             803739                37   37
# 7              RO     PORTO VELHO             548952                40   40
# 8              RS    PORTO ALEGRE            1492530                73   73
# 9              SP        CAMPINAS            1223237                51   51
# 10             SP      INDAIATUBA             260690                36   36
# ...

# %%
#Vamos fazer uns gráficos aí

import matplotlib.pyplot as plt

plt.hist(combustiveis_df['Valor de Venda'])
plt.title('Valor dos combustíveis - Nov/2021')

#Rótulo horizontal
plt.xlabel('Preço(em reais)')

#Rótulo horizontal
plt.ylabel('Números de Coletas')

#Traça uma linha vertical cruzando eixos
plt.axvline(combustiveis_df['Valor de Venda'].mean(), color = 'red')


plt.show()

# %%
# Segundo gráfico
c_mean = combustiveis_df['Valor de Venda'].groupby(by = combustiveis_df['Produto']).mean()

display(c_mean)
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
#definindo area do grafico

plt.figure(figsize = (10, 5))

#plotando gráfico
c_mean.plot(
    kind = 'barh',
    xlabel = 'Tipo de combustível',
    ylabel = 'Preço reais/litro',
    title = 'Média de preços por combustivel',
    color = 'purple',
    alpha = 0.5
)

plt.grid()
plt.show()
